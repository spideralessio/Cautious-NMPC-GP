# %%
import gpflow
import tensorflow as tf
from gpflow.ci_utils import ci_niter  # to speed up automated testing of this notebook
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
def getKernel():
    return gpflow.kernels.SquaredExponential()

# %%
X = np.arange(0,10,0.1)

# %%
y = np.sin(X)

# %%
y
# Out:
# array([ 0.        ,  0.09983342,  0.19866933,  0.29552021,  0.38941834,
#         0.47942554,  0.56464247,  0.64421769,  0.71735609,  0.78332691,
#         0.84147098,  0.89120736,  0.93203909,  0.96355819,  0.98544973,
#         0.99749499,  0.9995736 ,  0.99166481,  0.97384763,  0.94630009,
#         0.90929743,  0.86320937,  0.8084964 ,  0.74570521,  0.67546318,
#         0.59847214,  0.51550137,  0.42737988,  0.33498815,  0.23924933,
#         0.14112001,  0.04158066, -0.05837414, -0.15774569, -0.2555411 ,
#        -0.35078323, -0.44252044, -0.52983614, -0.61185789, -0.68776616,
#        -0.7568025 , -0.81827711, -0.87157577, -0.91616594, -0.95160207,
#        -0.97753012, -0.993691  , -0.99992326, -0.99616461, -0.98245261,
#        -0.95892427, -0.92581468, -0.88345466, -0.83226744, -0.77276449,
#        -0.70554033, -0.63126664, -0.55068554, -0.46460218, -0.37387666,
#        -0.2794155 , -0.1821625 , -0.0830894 ,  0.0168139 ,  0.1165492 ,
# ...

# %%
exact_model = gpflow.models.GPR((X, y), kernel=getKernel())

# %%
opt = gpflow.optimizers.Scipy()
opt.minimize(
    exact_model.training_loss,
    exact_model.trainable_variables,
    method="L-BFGS-B",
    options=dict(maxiter=ci_niter(20000)),
    tol=1e-11,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-715fe7f2e39b> in <module>
#       1 opt = gpflow.optimizers.Scipy()
# ----> 2 opt.minimize(
#       3     exact_model.training_loss,
#       4     exact_model.trainable_variables,
#       5     method="L-BFGS-B",
#
# ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/gpflow/optimizers/scipy.py in minimize(self, closure, variables, method, step_callback, compile, **scipy_kwargs)
#      86             scipy_kwargs.update(dict(callback=callback))
#      87
# ---> 88         return scipy.optimize.minimize(
#      89             func, initial_params, jac=True, method=method, **scipy_kwargs
#      90         )
#
# ~/miniconda3/envs/tensorflow/lib/python3.8/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
# ...
